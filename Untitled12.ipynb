# %%
pokemon = "Ponyta_Rapidash", "Sylveon", "Pikachu", "Trainers", "Energy", "Mew_Mewtwo", "Other_Pokemon", "Empty_Slots"
Number_of_slots_in_binder = [ 38, 13, 10, 19, 12, 10, 168, 162]
colors = ["red", "pink", "yellow", "white", "gold", "purple", "blue", "brown"]

# %%
plt.pie (Number_of_Pages_in_binder, labels = pokemon, colors = colors,
         autopct = '%1.1f%%', shadow = True, startangle = 90)
# Out:
# ([<matplotlib.patches.Wedge at 0x22e2c1207d0>,
# ...
#  [Text(-0.2835881662416224, 1.0628159539486195, 'Ponyta_Rapidash'),
#   Text(-0.6268387583867797, 0.9039209981984712, 'Sylveon'),
#   Text(-0.7704523427511715, 0.785113487050905, 'Pikachu'),
#   Text(-0.8919456123288659, 0.6437647277129158, 'Trainers'),
#   Text(-1.0265251484127362, 0.39527979922608014, 'Energy'),
#   Text(-1.0933570693090737, 0.12070757636483928, 'Mew_Mewtwo'),
#   Text(-0.5599453188640647, -0.9468163707299431, 'Other_Pokemon'),
#   Text(1.0619196962816824, 0.28692605083718, 'Empty_Slots')],
#  [Text(-0.1546844543136122, 0.5797177930628833, '8.3%'),
#   Text(-0.34191205002915254, 0.493047817199166, '2.7%'),
#   Text(-0.4202467324097298, 0.4282437202095845, '2.7%'),
#   Text(-0.48651578854301775, 0.35114439693431765, '2.7%'),
#   Text(-0.5599228082251287, 0.21560716321422552, '5.5%'),
#   Text(-0.5963765832594947, 0.06584049619900323, '2.7%'),
#   Text(-0.30542471938039895, -0.5164452931254234, '33.8%'),
# ...
